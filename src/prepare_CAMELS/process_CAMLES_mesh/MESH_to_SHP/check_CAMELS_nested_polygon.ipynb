# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
file = '/Users/guoqiang/Research/CTSM/CAMELS_basins/HCDN_nhru_final_671.gpkg'
shp = gpd.read_file(file)
lon_cen = shp['lon_cen'].values
lat_cen = shp['lat_cen'].values

# %%
# nest 1
# latrange = [41, 43]
# lonrange = [-75.5, -74]

# index = (lon_cen>=lonrange[0]) & (lon_cen<=lonrange[1]) & (lat_cen>=latrange[0]) & (lat_cen<=latrange[1])
# shp1 = shp[index]
# shp1.boundary.plot()

fig, ax = plt.subplots()
shp.loc[[37]].plot(ax=ax, color='g')
shp.loc[[36]].boundary.plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >

# %%
# nest2
fig, ax = plt.subplots()
shp.loc[[362]].plot(ax=ax, color='g')
shp.loc[[363]].boundary.plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >

# %%
# nest3
fig, ax = plt.subplots()
shp.loc[[357]].plot(ax=ax, color='g')
shp.loc[[358]].boundary.plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >

# %%
# nest4
fig, ax = plt.subplots()
shp.loc[[403]].plot(ax=ax, color='k')
shp.loc[[402]].plot(ax=ax, color='g')
shp.loc[[404]].boundary.plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >

# %%
# nest5
fig, ax = plt.subplots()
shp.loc[[610]].plot(ax=ax, color='k')
shp.loc[[611]].boundary.plot(ax=ax, color='r')
# Out:
# <AxesSubplot: >
