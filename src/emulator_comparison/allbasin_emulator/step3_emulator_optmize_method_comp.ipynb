# %%
# Build an emulator based on data from all basins
# Investigate different emulator set up and methods
# spatial CV

# %%
import sys, os, glob, pickle, toml, json
import pickle
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder

from multiprocessing import Pool, cpu_count
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor

sys.path.append("../../MOASMO_support")
from MOASMO_parameters import *

sys.path.append("/glade/u/home/guoqiang/CTSM_repos/ctsm_optz/MO-ASMO/src")
import NSGA2


def get_modified_KGE(obs,sim):
    ind = (~np.isnan(obs)) & (~np.isnan(sim))
    obs = obs[ind]
    sim = sim[ind]

    try:
        sd_sim=np.std(sim, ddof=1)
        sd_obs=np.std(obs, ddof=1)
        m_sim=np.mean(sim)
        m_obs=np.mean(obs)
        r=(np.corrcoef(sim,obs))[0,1]
        relvar=(float(sd_sim)/float(m_sim))/(float(sd_obs)/float(m_obs))
        bias=float(m_sim)/float(m_obs)
        kge=1.0-np.sqrt((r-1)**2 +(relvar-1)**2 + (bias-1)**2)
    except:
        kge = np.nan

    return kge, r, bias, relvar

def get_rmse(d1, d2):
    return ( np.nanmean( (d1-d2)**2 ) ) ** 0.5

# %%
ncpus = 10 # used for model train (RF can use all cpus; BP-NN can only use 5 for 5-fold cross validation)

# %% [markdown]
# # Load data for all basins
# From step-1 script

# %%
file = 'camels_627basin_allinfo.pkl'

if os.path.exists(file):
    # Load dataframes from the outfile
    with pd.HDFStore(file, 'r') as store:
        df_basin_info = store['df_basin_info']
        df_param_info = store['df_param_info']
        df_att = store['df_att']
else:
    print('File does not exist')

# print('df_basin_info')
# display(df_basin_info.iloc[[0]])

# print('df_param_info')
# display(df_param_info.iloc[[0]])

# print('df_att')
# display(df_att.iloc[[0]])

# %%
# model outputs
inpath_moasmo = "/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange"

file_defa_param = 'camels_627basin_ctsm_defa_param.csv'
if os.path.isfile(file_defa_param):
    df_param_defa = pd.read_csv(file_defa_param)
else:
    print('file_defa_param does not exist')

file_all_param = 'camels_627basin_ctsm_all_param.csv.gz'
if os.path.isfile(file_all_param):
    df_param = pd.read_csv(file_all_param, compression='gzip')
else:
    print('file_all_param does not exist')

file_all_metric = 'camels_627basin_ctsm_all_metric.csv.gz'
file_all_basinid = 'camels_627basin_ctsm_all_basinid.csv.gz'

if os.path.isfile(file_all_param):
    df_metric = pd.read_csv(file_all_metric, compression='gzip')
    df_basinid = pd.read_csv(file_all_basinid, compression='gzip')
else:
    print('file_all_param does not exist')

# remove nan values (some failed models)
index = np.isnan(np.sum(df_metric.values, axis=1))
df_param = df_param[~index]
df_metric = df_metric[~index]
df_basinid = df_basinid[~index]

df_param.index = np.arange(len(df_param))
df_metric.index = np.arange(len(df_metric))
df_basinid.index = np.arange(len(df_basinid))

print('Number of nan samples:', np.sum(index))
print("Number of original parameter sets:", len(index))
print("Number of final parameter sets:", len(df_param))
# Out:
# Number of nan samples: 3309
# Number of original parameter sets: 250800
# Number of final parameter sets: 247491

# %%
# Load attributes for training
attlist = toml.load('camels_attributes_fortrain.toml')
att_Xie2021 = attlist['att_Xie2021']

useattrs = list(att_Xie2021.keys())
print("The number of attributes used:", len(useattrs))
print(useattrs)
# Out:
# The number of attributes used: 27
# ['p_mean', 'pet_mean', 'aridity', 'p_seasonality', 'frac_snow', 'high_prec_freq', 'high_prec_dur', 'low_prec_freq', 'low_prec_dur', 'mean_elev', 'mean_slope', 'area_gauges2', 'frac_forest', 'lai_max', 'lai_diff', 'dom_land_cover_frac', 'dom_land_cover', 'soil_depth_pelletier', 'soil_depth_statsgo', 'soil_porosity', 'soil_conductivity', 'max_water_content', 'sand_frac', 'silt_frac', 'clay_frac', 'carbonate_rocks_frac', 'geol_permeability']

# %%
# load parameter upper/lower bounds for all basins

file_param_lb = 'camels_627basin_ctsm_all_param_lb.csv.gz'
file_param_ub = 'camels_627basin_ctsm_all_param_ub.csv.gz'

if os.path.isfile(file_param_lb):
    df_param_lb = pd.read_csv(file_param_lb, compression='gzip')
    df_param_ub = pd.read_csv(file_param_ub, compression='gzip')

else:
    
    param_lb_values = df_param_defa.values.copy()
    param_ub_values = df_param_defa.values.copy()
    
    for i in range(len(df_basin_info)):
        file = f"{inpath_moasmo}/level1_{i}_MOASMOcalib/param_sets/all_default_parameters.pkl"
        dfi = pd.read_pickle(file)
    
        for j in range(len(dfi['Parameter'].values)):
            indj = np.where(df_param_defa.columns.values==dfi['Parameter'].values[j])[0][0]
            param_lb_values[i, indj] = dfi['Lower'].values[j]
            param_ub_values[i, indj] = dfi['Upper'].values[j]
    
    df_param_lb = pd.DataFrame(param_lb_values, columns=df_param_defa.columns.values)
    df_param_ub = pd.DataFrame(param_ub_values, columns=df_param_defa.columns.values)
    
    df_param_lb.to_csv(file_param_lb, index=False, compression='gzip')
    df_param_ub.to_csv(file_param_ub, index=False, compression='gzip')

# %% [markdown]
# # create model inputs and outputs
# parameters + attributes -> obj funcs

# %%
# Prepare model input and output

df_input = df_param.copy()
df_input["hru_id"] = df_basinid["hru_id"]
df_input = df_input.merge(df_att[useattrs + ["hru_id"]], on="hru_id", how="left")
df_input = df_input.drop(["hru_id"], axis=1)

inputnames = list(df_param.columns) + useattrs
# print("Input parameters:", list(df_param.columns))
# print("Input attribuets:",  useattrs)

# if there is string attributes in the input, convert them to one-hot encoding
for att in useattrs:
    if df_input[att].dtype == "object":
        print('convert', att, 'to one-hot encoding')
        enc = OneHotEncoder(sparse=False)
        enc.fit(df_input[[att]])
        encnames = [att + "_" + str(i) for i in range(len(enc.categories_[0]))]
        print('new columns:', encnames)
        df_enc = pd.DataFrame(enc.transform(df_input[[att]]), columns=encnames)
        df_input = pd.concat([df_input, df_enc], axis=1)
        df_input = df_input.drop([att], axis=1)
        inputnames = [i for i in inputnames if i != att] + encnames


# convert to numpy array for training / testing
# print("Input parameters after adjustment:", list(df_param.columns))
# print("Input attribuets after adjustment:",  useattrs)

x_all = df_input[inputnames].values.copy()
print("Input shape:", x_all.shape)
# Out:
# convert dom_land_cover to one-hot encoding
# new columns: ['dom_land_cover_0', 'dom_land_cover_1', 'dom_land_cover_2', 'dom_land_cover_3', 'dom_land_cover_4', 'dom_land_cover_5', 'dom_land_cover_6', 'dom_land_cover_7', 'dom_land_cover_8', 'dom_land_cover_9', 'dom_land_cover_10', 'dom_land_cover_11']
# Input shape: (247491, 65)

# %%
# check what metrics to be used as optimzation targets

# fig = plt.figure(figsize=[10, 4])

# flag = 1
# for i in ['kge', 'mae', 'n_mae', 'nse', 'cc', 'rmse', 'max_mon_abs_err', 'n_max_mon_abs_err',  'kge_log_q']:
#     fig.add_subplot(3, 3, flag)
#     flag = flag + 1
#     plt.plot(df_metric[i].values)
#     plt.title(i)
    
# plt.tight_layout()
# plt.show()

# plt.hist(df_output[["rmse"]].values)
# plt.hist(df_output[["kge"]].values, np.arange(-10, 1, 0.01))

# %% [markdown]
# ## Outputs

# %%
# use normalized kge as output

df_output = df_metric.copy()
y_all = df_output[["kge"]].values.copy()
y_all = y_all / (2 - y_all) # normalize KGE

print("Output shape:", y_all.shape)
# Out:
# Output shape: (247491, 1)

# %% [markdown]
# # Train / Test emulators

# %%
def get_cv_indices(df_basinid, nfold=5):
    from sklearn.model_selection import GroupKFold

    # Initialize GroupKFold
    group_kfold = GroupKFold(n_splits=nfold)

    # Dictionary to store train and test indices
    cv_indices = {}

    # Cross-validation process to save indices
    # does not depend on random seeds
    for fold, (train_index, test_index) in enumerate(group_kfold.split(df_basinid, groups=df_basinid['basin_num'])):
        
        train_basin = np.unique(df_basinid.iloc[train_index]['basin_id'].values)
        test_basin = np.unique(df_basinid.iloc[test_index]['basin_id'].values)

        cv_indices[fold] = {'train_index': train_index, 'test_index': test_index, 'train_basin': train_basin, 'test_basin': test_basin} 
    return cv_indices

# Get the indices
nfold = 5
cv_indices = get_cv_indices(df_basinid, nfold)

# plot test basin batches
fig = plt.figure(figsize=(6, 3))
for fold in range(len(cv_indices)):
    test_basin = cv_indices[fold]['test_basin']
    lat = df_basin_info.iloc[test_basin]['lat_cen'].values
    lon = df_basin_info.iloc[test_basin]['lon_cen'].values
    plt.scatter(lon, lat, 15, label=f'fold {fold}')

plt.legend()
plt.show()

# %% [markdown]
# # Train one final emulator model

# %%
# train an RF model using all samples

outfile = '/glade/work/guoqiang/CTSM_CAMELS/analyses/emulator_comp/allbasin_emulator_allsample_rf.pkl'
if os.path.isfile(outfile):
    with open(outfile, 'rb') as file:
        rf_model = pickle.load(file)
else:
    # Initialize a new MLPRegressor for each fold
    modelconfig = {'n_estimators': 100, 'random_state': 42, 'max_depth': 40}
    # Initialize a new RandomForestRegressor for each fold
    rf_model = RandomForestRegressor(**modelconfig, n_jobs=ncpus)
            
    # Train the model
    rf_model.fit(x_all, y_all)
    
    with open(outfile, 'wb') as file:
        pickle.dump(rf_model, file)
        
# Predict on the test set
y_pred = rf_model.predict(x_all)

# evaluation
rmse_rf = get_rmse(y_all[:, 0], y_pred)
print(rmse_rf)

plt.scatter(y_all[:,0], y_pred, 1)
plt.xlabel('Raw input')
plt.ylabel('Prediction')
plt.show()
# Out:
# 0.029377721377637375

# %%
# train an ANN model using all samples

x_all_mean = np.nanmean(x_all, axis=0)
x_all_std = np.nanstd(x_all, axis=0)
x_all_norm = (x_all - x_all_mean) / x_all_std

y_all_mean = np.nanmean(y_all, axis=0)
y_all_std = np.nanstd(y_all, axis=0)
y_all_norm = (y_all - y_all_mean) / y_all_std


outfile = '/glade/work/guoqiang/CTSM_CAMELS/analyses/emulator_comp/allbasin_emulator_allsample_ann_meanstdnorm.pkl'
if os.path.isfile(outfile):
# if False:
    with open(outfile, 'rb') as file:
        bp_model = pickle.load(file)
else:
    # Initialize a new MLPRegressor for each fold
    modelconfig = {'hidden_layer_sizes': (200,), 'max_iter': 1000, 'alpha': 0.0001, 'random_state': 42, 'early_stopping': True}
    bp_model = MLPRegressor(**modelconfig)
        
    # Train the model
    bp_model.fit(x_all_norm, y_all_norm)
    
    with open(outfile, 'wb') as file:
        pickle.dump(bp_model, file)
        
# Predict on the test set
y_pred_norm = bp_model.predict(x_all_norm)
y_pred = y_pred_norm*y_all_std+y_all_mean


# evaluation
rmse_bp = get_rmse(y_all[:, 0], y_pred)
print(rmse_bp)

plt.scatter(y_all[:,0], y_pred, 1)
plt.xlabel('Raw input')
plt.ylabel('Prediction')
plt.show()
# Out:
# 0.08532857250975963

# %% [markdown]
# # Get optimized parameters from the emulator

# %%
em_model = rf_model

# %%
# select one basin for test

# file_sm_rf_optmz = f'/glade/work/guoqiang/CTSM_CAMELS/analyses/emulator_bpnn_allbasin_optmz_outputs.npz'
# if os.path.isfile(file_sm_rf_optmz):
#     d = np.load(file_sm_rf_optmz)
#     bestx_sm_all_bpnn = d['bestx_sm_all_bpnn']
#     besty_sm_all_bpnn = d['besty_sm_all_bpnn']

# else:

if True:
    bestx_sm_all_bpnn = []
    besty_sm_all_bpnn = []

    param_names = df_param_info['Parameter'].values
    
    # for tarbasin in range(len(df_basin_info)):
    for tarbasin in range(1):
        print(tarbasin)
    
        index = np.where(df_basinid["basin_num"].values == tarbasin)[0]
        hruid = df_basinid["hru_id"].values[index[0]]
        
        attnames = [i for i in inputnames if not i in param_names]
        # attrvalues = df_input.iloc[index[0]][attnames].values
        
        param_lb_mean = df_param_lb.values[tarbasin, :]
        param_ub_mean = df_param_ub.values[tarbasin, :]

        attrvalues = x_all[index[0], len(param_lb_mean):] # same with df_input
        if np.any( attrvalues != df_input.iloc[index[0]][attnames].values):
            print('Warning! att problem')
    
        x_tar = x_all[index, :]
        y_tar = y_all[index, :]
        xlb_mean = np.hstack([param_lb_mean, attrvalues])
        xub_mean = np.hstack([param_ub_mean, attrvalues])


    # np.savez_compressed(file_sm_rf_optmz, bestx_sm_all_bpnn=bestx_sm_all_bpnn, besty_sm_all_bpnn=besty_sm_all_bpnn)
# Out:
# 0

# %%
print('best input metric', np.max(y_tar))
print('best predicted metric using input param', np.max(em_model.predict(x_tar)))
# Out:
# best input metric 0.2720855291621706
# best predicted metric using input param 0.19475667631238916

# %% [markdown]
# ## LHS optimization

# %%
        # try LHS
        num1 = 10000000
        num2 = np.sum(xlb_mean != xub_mean)
        init_factors = sampling.lh(num1, num2)
        
        x_lh = np.zeros([num1, len(xlb_mean)])
        for i in range(len(xlb_mean)):
            x_lh[:, i] = xlb_mean[i]
        
        
        indi = np.where(xlb_mean != xub_mean)[0]
        for i in range(len(indi)):
            ii = indi[i]
            x_lh[:,ii] = xlb_mean[ii] + (xub_mean[ii] - xlb_mean[ii])*init_factors[:,i]
        
        y_pred = rf_model.predict(x_lh)

        y_pred.max()

# %%
# check whether the LHS parameters follow the same distribution with the input parameters
fig = plt.figure(figsize=[12,8])
for i in range(65):
    fig.add_subplot(6, 11, i+1)
    data = [x_lh[:, i], x_tar[:, i]]
    plt.boxplot(data, labels=['x_lh', 'x_tar'])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Scipy differential_evolution optimization

# %%
# Python optimization

from scipy.optimize import differential_evolution

# Define the objective function to maximize rf_model's output
def objective_function(x):
    # x is a vector of feature values
    # We return the negative because we want to maximize the output
    return -rf_model.predict([x])[0]

# Define the bounds for each feature
bounds = list(zip(xlb_mean, xub_mean))

# Perform the optimization using differential evolution
result = differential_evolution(objective_function, bounds, strategy='best1bin', maxiter=1000, popsize=15, tol=0.01, workers=ncpus)

# The optimized feature values
optimized_features = result.x

# The maximum predicted output
max_output = -result.fun

# print("Optimized features:", optimized_features)
print("Maximum predicted output:", max_output)
# Out:
# Maximum predicted output: 0.28062291916925786

# %% [markdown]
# ## Scipy basinhopping optimization

# %%
import numpy as np
from scipy.optimize import basinhopping, Bounds

# Assuming rf_model is your trained random forest model
# xlb_mean and xub_mean are your lower and upper bounds respectively

# Define the objective function to maximize rf_model's output
def objective_function(x):
    # x is a vector of feature values
    # We return the negative because we want to maximize the output
    return -rf_model.predict([x])[0]

bounds = Bounds(xlb_mean, xub_mean)

# Initial guess for the optimizer (midpoint of the bounds)
# initial_guess = (xlb_mean + xub_mean) / 2
xbest = x_tar[np.argmax(y_tar),:]
initial_guess = xbest

# Perform the optimization using basinhopping
result = basinhopping(objective_function, initial_guess, niter=100, stepsize=0.5, minimizer_kwargs={"method": "L-BFGS-B", "bounds": bounds})

# The optimized feature values
optimized_features = result.x

# The maximum predicted output
max_output = -result.fun

# print("Optimized features:", optimized_features)
print("Maximum predicted output:", max_output)
# Out:
# Maximum predicted output: 0.27533282140618587

# %% [markdown]
# ## Pymoo GA optimization

# %%
ga_all_solutions = []
ga_all_outputs = []

# %%
from pymoo.algorithms.soo.nonconvex.ga import GA
from pymoo.optimize import minimize
from pymoo.core.problem import Problem
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.operators.crossover.sbx import SimulatedBinaryCrossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.termination import get_termination

# Assuming em_model is your trained model
# xlb_mean and xub_mean are your lower and upper bounds respectively

class MyProblem(Problem):
    def __init__(self):
        super().__init__(n_var=len(xlb_mean), n_obj=1, n_constr=0, xl=xlb_mean, xu=xub_mean, elementwise_evaluation=False)

    def _evaluate(self, x, out, *args, **kwargs):
        # Predict expects a 2D array, so we pass x directly
        out["F"] = -em_model.predict(x)  # Return negative to maximize


for i in range(100): # run the model 40 times

    problem = MyProblem()
    
    algorithm = GA(
        pop_size=100,
        sampling=FloatRandomSampling(),
        crossover=SimulatedBinaryCrossover(prob=0.9, eta=15),
        mutation=PolynomialMutation(eta=20),
        eliminate_duplicates=True
    )
    
    res = minimize(problem,
                   algorithm,
                   termination=get_termination("n_gen", 100),
                   verbose=False)
    
    optimized_features = res.X
    max_output = -res.F
    
    ga_all_solutions.append(optimized_features)
    ga_all_outputs.append(max_output)
    
    # print("Optimized features:", optimized_features)
    # print("Maximum predicted output:", max_output)
    
    population = res.pop
    all_solutions = [ind.X for ind in population]
    all_outputs = [-ind.F[0] for ind in population]
    
    # print("All outputs:", all_outputs)

# %%
plt.plot(ga_all_outputs)

# %%
# Initialize an empty matrix to store the MSE values

ga_all_solutions = np.array(ga_all_solutions)

n_rows = ga_all_solutions.shape[0]

mse_matrix = np.zeros((n_rows, n_rows))

# Calculate MSE between each pair of rows
for i in range(n_rows):
    for j in range(n_rows):
        mse = np.mean((ga_all_solutions[i] - ga_all_solutions[j]) ** 2) ** 0.5
        mse_matrix[i, j] = mse

plt.imshow(mse_matrix)

# %% [markdown]
# ## Pymoo NSGA-II

# %%
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.optimize import minimize
from pymoo.core.problem import Problem
from pymoo.operators.sampling.rnd import FloatRandomSampling
from pymoo.operators.crossover.sbx import SimulatedBinaryCrossover
from pymoo.operators.mutation.pm import PolynomialMutation
from pymoo.termination import get_termination

class MyProblem(Problem):
    def __init__(self):
        super().__init__(n_var=len(xlb_mean), n_obj=1, n_constr=0, xl=xlb_mean, xu=xub_mean, elementwise_evaluation=False)

    def _evaluate(self, x, out, *args, **kwargs):
        # Predict expects a 2D array, so we pass x directly
        predictions = em_model.predict(x)
        out["F"] = -predictions  # Return negative to maximize

# Define problem instance
problem = MyProblem()

# Define NSGA-II algorithm with custom sampling, crossover, and mutation
algorithm = NSGA2(
    pop_size=100,
    sampling=FloatRandomSampling(),
    crossover=SimulatedBinaryCrossover(prob=0.9, eta=15),
    mutation=PolynomialMutation(eta=20),
    eliminate_duplicates=True
)

# Perform the optimization
res = minimize(problem,
               algorithm,
               termination=get_termination("n_gen", 100),
               verbose=False)

# Extract optimized features and the maximum predicted output
optimized_features = res.X
max_output = -res.F

# Output the optimized results
# print("Optimized features:", optimized_features)
# print("Maximum predicted output:", max_output)

# Get the entire population of optimized solutions
population = res.pop
all_solutions = [ind.X for ind in population]
all_outputs = [-ind.F[0] for ind in population]

# Output all solutions
# print("All solutions:", all_solutions)
# print("All outputs:", all_outputs)

# %% [markdown]
# # Save optimized parameters to parameter pkl files

# %%
        # generate a parameter dataframe for next trial

        path_CTSM_case = f'/glade/work/guoqiang/CTSM_CAMELS/Calib_HH_MOASMO_bigrange/level1_{tarbasin}'
        outpath = f'{inpath_moasmo}/level1_{tarbasin}_MOASMOcalib/param_sets_emutest'
        os.makedirs(outpath, exist_ok=True)

        df_info = pd.read_pickle(f'{inpath_moasmo}/level1_{tarbasin}_MOASMOcalib/param_sets/paramset_iter0_trial0.pkl')
        df_info['Factor'] = np.nan
        df_info['Value'] = np.nan


        ga_all_solutions_array = np.array(ga_all_solutions)

        indexp = []
        for p in df_info['Parameter'].values:
            indexp.append(np.where(param_names == p)[0][0])


        for i in range(len(ga_all_solutions)):
            # outfile = f'{outpath}/paramset_iter{iterflag+1}_trial{i}.csv'
            outfile = f'{outpath}/paramset_iter1_trial{i}.pkl'
            print('Generating parameter file:', outfile)

            dfi = df_info.copy()
            dfi['Value'] = ga_all_solutions_array[i, indexp]

            # process binded parameters
            dfi = check_and_generate_binded_parameters(dfi, path_CTSM_case)

            # write
            dfi.to_pickle(outfile)
# Out:
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial0.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial1.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial2.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial3.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial4.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial5.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial6.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial7.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial8.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial9.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial10.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial11.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial12.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial13.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial14.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial15.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial16.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial17.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial18.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial19.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial20.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial21.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial22.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial23.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial24.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial25.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial26.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial27.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial28.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial29.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial30.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial31.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial32.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial33.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial34.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial35.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial36.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial37.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial38.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial39.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial40.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial41.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial42.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial43.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial44.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial45.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial46.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial47.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial48.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial49.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial50.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial51.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial52.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial53.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial54.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial55.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial56.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial57.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial58.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial59.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial60.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial61.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial62.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial63.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial64.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial65.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial66.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial67.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial68.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial69.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial70.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial71.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial72.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial73.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial74.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial75.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial76.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial77.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial78.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial79.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial80.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial81.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial82.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial83.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial84.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial85.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial86.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial87.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial88.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial89.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial90.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial91.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial92.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial93.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial94.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial95.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial96.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial97.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial98.pkl
# Generating parameter file: /glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_0_MOASMOcalib/param_sets_emutest/paramset_iter1_trial99.pkl
