# %%
import pandas as pd
import numpy as np
import os, sys, glob

# %%
d = np.nan * np.zeros([65, 2])
flag = 0
for i in range(1, 627, 10):
    file1 = f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_{i}_MOASMOcalib/param_sets_normKGE/intermediate_output_iter1.pkl.npz'
    file2 = f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_{i}_MOASMOcalib/param_sets_emutest/ga_output_iter1.npz'
    d1 = np.load(file1)
    d2 = np.load(file2)
    d[flag, 0] = np.mean(d1['y_resample'])
    d[flag, 1] = np.mean(d2['ga_all_outputs'])
    flag = flag + 1

# %%
import matplotlib.pyplot as plt
plt.plot(d)
plt.legend(['one', 'all'])

# %%
plt.plot(d[:,1]-d[:,0])

# %%
tarbasin = 31

v1 = []
for i in range(40):
    file=f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_{tarbasin}_MOASMOcalib/ctsm_outputs_normKGE/iter1_trial{i}/evaluation_metric.csv'
    df=pd.read_csv(file)
    v1.append(df.values[0])
v1 = np.array(v1)

v2 = []
for i in range(100):
    file=f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_{tarbasin}_MOASMOcalib/ctsm_outputs_emutest/iter1_trial{i}/evaluation_metric.csv'
    df=pd.read_csv(file)
    v2.append(df.values[0])

v2 = np.array(v2)


v3 = []
for i in range(40):
    file=f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/Calib_HH_MOASMO_bigrange/level1_{tarbasin}_MOASMOcalib/ctsm_outputs/iter1_trial{i}/evaluation_metric.csv'
    df=pd.read_csv(file)
    v3.append(df.values[0])

v3 = np.array(v3)

# %%
plt.scatter(v1[:,0], v1[:,1])
plt.scatter(v2[:,0], v2[:,1])

# %%
plt.scatter(v1[:,0], v1[:,1])
plt.scatter(v3[:,0], v3[:,1])
