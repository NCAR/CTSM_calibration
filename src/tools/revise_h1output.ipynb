# %%
# we may need to change target variables after creating cases
import numpy as np
import xarray as xr
import glob, os, sys

# %%
"hist_fincl2 = 'QRUNOFF','H2OSNO','ZWT','SOILWATER_10CM','EFLX_LH_TOT','QDRAI','QOVER','RAIN'"
# Out:
# "hist_fincl2 = 'QRUNOFF','H2OSNO','ZWT','SOILWATER_10CM','EFLX_LH_TOT','QDRAI','QOVER','RAIN'"

# %%
# h0
basin = 'level1_60'
path = '/glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO'
files = glob.glob(f'{path}/{basin}_SpinupFiles/archive/lnd/hist/*.clm2.h0.*.nc')
files.sort()
ds = xr.open_dataset(files[0])
ds
# Out:
# <xarray.Dataset>
# Dimensions:                        (levgrnd: 25, levsoi: 20, levlak: 10,
#                                     levdcmp: 1, time: 1, hist_interval: 2,
#                                     lndgrid: 1, cft: 64, glc_nec: 10, ltype: 9,
#                                     natpft: 15, nvegwcs: 4)
# Coordinates:
#   * levgrnd                        (levgrnd) float32 0.01 0.04 ... 28.87 42.0
#   * levsoi                         (levsoi) float32 0.01 0.04 0.09 ... 6.94 8.03
#   * levlak                         (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * levdcmp                        (levdcmp) float32 1.0
#   * time                           (time) object 1951-02-01 00:00:00
# Dimensions without coordinates: hist_interval, lndgrid, cft, glc_nec, ltype,
#                                 natpft, nvegwcs
# Data variables: (12/261)
#     mcdate                         (time) int32 ...
#     mcsec                          (time) int32 ...
# ...

# %%
ds.QFLX_EVAP_TOT.values
# Out:
# array([[1.1702859]], dtype=float32)

# %%
ds.SNOWLIQ.values
# Out:
# array([[1.0096116]], dtype=float32)

# %%
ds.H2OSNO.values
# Out:
# array([[58.852303]], dtype=float32)

# %%
ds.SNOW_DEPTH.values
# Out:
# array([[0.20698124]], dtype=float32)
