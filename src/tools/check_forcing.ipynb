# %%
import xarray as xr
import numpy as np
import time, glob
import matplotlib.pyplot as plt
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib
import warnings
warnings.filterwarnings("ignore")

# %%
# ds=xr.open_mfdataset(glob.glob('/glade/work/guoqiang/CTSM_CAMELS/Calib_HH_MOASMO/level1_502_SubsetForcing/TPQWL/subset_clmforc.E5LEME.c2023.010x010.TPQWL.*.nc'))
# ds=xr.open_mfdataset(glob.glob('/glade/work/guoqiang/CTSM_CAMELS/Calib_HH_MOASMO/level1_502_SubsetForcing/Precip/subset_clmforc.E5LEME.c2023.010x010.Precip.*.nc'))
ds=xr.open_mfdataset(glob.glob('/glade/work/guoqiang/CTSM_CAMELS/Calib_HH_MOASMO/level1_502_SubsetForcing/Solar/subset_clmforc.E5LEME.c2023.010x010.Solar.*.nc'))
for v in ds.data_vars:
    print(v, np.sum(ds[v].values<0))

font = {'size': 10}

matplotlib.rc('font', **font)

fig, axs = plt.subplots(10, 4, figsize=[20, 20])
axs = axs.flatten()

flag = 0
# for v in ['FLDS', 'PSRF', 'QBOT', 'TBOT', 'WIND']:
for v in ds.data_vars:
    if not v in ['LONGXY','LATIXY','EDGEE','EDGEW','EDGES','EDGEN']:
        for t in range(0, 20):
            if flag < 40:
                ds.sel(time='1982-02-08').isel(time=t)[v].plot(ax=axs[flag])
                flag=flag+1

plt.tight_layout()
plt.show()
# Out:
# LONGXY 0
# LATIXY 0
# EDGEE 0
# EDGEW 0
# EDGES 0
# EDGEN 0
# FSDS 0
