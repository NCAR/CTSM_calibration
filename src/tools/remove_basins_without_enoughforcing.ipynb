# %%
import os, glob
import xarray as xr
import numpy as np

# %%
# 1

# folders = glob.glob(f'/glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/*_SubsetForcing')
# folders.sort()

# num = 0
# rmfolders = []
# for f in folders:
    
#     rmflag = False
    
#     file = f'{f}/TPQWL/inout_list_timemerge.txt'
#     if not os.path.isfile(file):
#         print(f'{file} does not exist')
#         rmflag = True
#     else:
#         files = glob.glob(f'{f}/TPQWL/subset_clmforc.E5LEME.c2023.010x010.TPQWL.*.nc')
#         if len(files)<5:
#             print('Not enough TPQWL files')
#             rmflag = True
            
#     if rmflag == True:
#         num = num + 1
#         os.system(f'rm -r {f}')
#         f = f.replace('_SubsetForcing', '')
#         os.system(f'rm -r {f}')
#         rmfolders.append(f)
        
# rmfolders.append('/glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_13')

# cmdfile = '/glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/submission/create_cases_add.txt'

# with open(cmdfile, 'w') as f:
#     for ff in rmfolders:
#         n = ff.split('/')[-1]
#         line = f'python /glade/u/home/guoqiang/CTSM_repos/CTSM_calibration/src/calibration/main_CC.py /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/configuration/{n}_config.toml'
#         f.write(line+'\n')

# %%
# 2

folders = glob.glob(f'/glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/*_SubsetForcing')
folders.sort()

num = 0
rmfolders = []
for f in folders:
    
    rmflag = False
    
    files = glob.glob(f'{f}/Solar/subset_clmforc.E5LEME.c2023.010x010.Solar.1*.nc')[0]
    ds = xr.open_dataset(files)
    
    if len(ds.lat)==1 or len(ds.lon)==1:
        print('lat/lon dim=1 for', f)
        rmflag = True
    
    
    if rmflag == True:
        num = num + 1
        os.system(f'rm -r {f}')
        f = f.replace('_SubsetForcing', '')
        os.system(f'rm -r {f}')
        rmfolders.append(f)
# Out:
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_104_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_109_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_10_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_111_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_116_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_117_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_11_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_120_SubsetForcing
# lat/lon dim=1 for /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/level1_121_SubsetForcing
# ...

# %%
index = [ np.arange(0, 30), np.arange(30, 60), np.arange(60, 90), np.arange(90, 120), np.arange(120, 150), np.arange(150, 182)]

for i in range(len(index)):
    indexi = index[i]

    cmdfile = f'/glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/submission/create_cases_add{i}.txt'

    with open(cmdfile, 'w') as f:
        for ff in np.array(rmfolders)[indexi]:
            n = ff.split('/')[-1]
            line = f'python /glade/u/home/guoqiang/CTSM_repos/CTSM_calibration/src/calibration/main_CC.py /glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Calib_all_HH_MOASMO/configuration/{n}_config.toml'
            f.write(line+'\n')
