# %%
import numpy as np
import xarray as xr
import glob
import matplotlib.pyplot as plt

# %%
files = glob.glob(f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/LongTermSimu/Defa/level1_100/level1_100_DefaultSimu.clm2.h0.*.nc')
files.sort()

# %%
d = []
for f in files:
    ds = xr.open_dataset(f)
    # d.append(np.squeeze(ds.ZWT.values))
    d.append(np.squeeze(ds.QRUNOFF.values))

# %%
d = np.array(d)

# %%
plt.plot(d)
