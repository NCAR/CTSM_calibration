# %% [markdown]
# # Parameters have similar performance in the calibration period (e.g., normKGE) can be different during the validation period and long term simulation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, sys, glob

# %% [markdown]
# # Load metrics

# %%
# load defa metrics

csvs = ['evaluation_metrics_5y_test.csv', 'evaluation_metrics_Ally_test.csv',
        'evaluation_metrics_train.csv', 'evaluation_metrics_ally.csv'] # 5y test period, all year test (no train period), train, all years

df_defa = []
for basin in range(627):
    pathb = f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/LongTermSimu/Defa/level1_{basin}/'
    files = [f'{pathb}/{c}' for c in csvs]
    dfb = pd.concat(map(pd.read_csv, files))
    dfb['basin'] = basin
    dfb['eval'] = ['test_5y', 'test_ally', 'train', 'ally']
    dfb['param'] = 'Defa'
    df_defa.append(dfb)
df_defa = pd.concat(df_defa)

# %%
# load optmz metrics
df_optmz = []
for basin in range(627):

    df_b = []
    for r in range(1, 6):
        pathb = f'/glade/campaign/cgd/tss/people/guoqiang/CTSM_CAMELS_proj/LongTermSimu/LSEallbasin/level1_{basin}/normKGEr{r}'
        files = [f'{pathb}/{c}' for c in csvs]
        if not os.path.isfile(files[0]):
            print('Warning! File does not exist for', basin)
            dfb = dfb.copy()
            dfb[:]=np.nan
            dfb['basin'] = basin
            dfb['eval'] = ['test_5y', 'test_ally', 'train', 'ally']
            dfb['param'] = f'normKGEr{r}'
        else:
            dfb = pd.concat(map(pd.read_csv, files))
            dfb['basin'] = basin
            dfb['eval'] = ['test_5y', 'test_ally', 'train', 'ally']
            dfb['param'] = f'normKGEr{r}'
        df_b.append(dfb)

    df_b = pd.concat(df_b)
    
    df_optmz.append(df_b)
df_optmz = pd.concat(df_optmz)
# Out:
# Warning! File does not exist for 8
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# Warning! File does not exist for 13
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# Warning! File does not exist for 119
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# Warning! File does not exist for 128
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# Warning! File does not exist for 329
# Warning! File does not exist for 329
# Warning! File does not exist for 329
# Warning! File does not exist for 329
# Warning! File does not exist for 329
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# Warning! File does not exist for 464
# Warning! File does not exist for 464
# Warning! File does not exist for 464
# Warning! File does not exist for 464
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# Warning! File does not exist for 563
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan
# /glade/derecho/scratch/guoqiang/tmp/ipykernel_45741/3466875563.py:12: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'nan' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dfb[:]=np.nan

# %%
# merge them into one df
df_all = pd.concat([df_defa, df_optmz])

# %% [markdown]
# # Comparison

# %%
# train vs test
print('Defa')
for e in ['test_5y', 'test_ally', 'train', 'ally']:
    d1 = df_defa[df_defa['eval']==e]['kge'].values
    print(e, np.nanmean(d1), np.nanmedian(d1))


print('Optmz')

for r in range(1, 6):
    print('Optmz rank', r)
    for e in ['test_5y', 'test_ally', 'train', 'ally']:
        d2 = df_optmz[(df_optmz['eval']==e) & (df_optmz['param']==f'normKGEr{r}') ]['kge'].values
        print(e, np.nanmean(d2), np.nanmedian(d2))
# Out:
# Defa
# test_5y -0.35081782355558355 0.2111565437909206
# test_ally -0.09273546062866532 0.244204298708747
# train -1.2126849022199788 0.1954205578883867
# ally -0.10862894330171279 0.2395336749424387
# Optmz
# Optmz rank 1
# test_5y 0.2874923883681338 0.44160014926512503
# test_ally 0.3139578388503923 0.46511007897611145
# train 0.4221492974379981 0.5195068810994925
# ally 0.31881178225594736 0.4786870918284719
# Optmz rank 2
# test_5y 0.24219810213720055 0.4375137620067151
# test_ally 0.25872346424380444 0.4685923689380481
# train 0.3532569849916563 0.5198062969858022
# ally 0.26825922415302583 0.4756900776419823
# Optmz rank 3
# test_5y 0.16972257938259366 0.43352132462166365
# test_ally 0.2982587762239018 0.4652565665148025
# train 0.3019849095652104 0.5148457335960537
# ally 0.31005351373055723 0.4740631349524953
# Optmz rank 4
# test_5y 0.2813605645310039 0.4345736677703737
# test_ally 0.32585257444662963 0.4656501265934004
# train 0.41151944447866173 0.5145874351253513
# ally 0.330934089406821 0.4768103632099646
# Optmz rank 5
# test_5y 0.3285747809296783 0.4372859403161512
# test_ally 0.33417502847749636 0.4632126620061211
# train 0.4096670392753784 0.5145405078654086
# ally 0.33647184400404184 0.4732254337578357

# %%
# optmz_kge_train =  df_optmz[df_optmz['eval']=='train']['kge'].values
# optmz_kge_test =  df_optmz[df_optmz['eval']=='test_5y']['kge'].values

# defa_kge_train =  df_defa[df_defa['eval']=='train']['kge'].values
# defa_kge_test =  df_defa[df_defa['eval']=='test_5y']['kge'].values


# fig = plt.figure(figsize=[10, 5])

# fig.add_subplot(1,2,1)
# plt.scatter(defa_kge_train, defa_kge_test, 20, label='defa', alpha=0.5, )
# plt.scatter(optmz_kge_train, optmz_kge_test, 20, label='optmz', alpha=0.5, )
# plt.plot([-1,1],[-1,1], 'k')
# plt.xlim(-1, 1)
# plt.ylim(-1, 1)
# plt.xlabel("Train KGE'")
# plt.ylabel("Test KGE'")
# plt.legend()

# fig.add_subplot(1,2,2)
# plt.hist(optmz_kge_train - defa_kge_train, np.arange(-0.5, 2, 0.05) , label='otpmz-defa: train', alpha=0.5, )
# plt.hist(optmz_kge_test - defa_kge_test, np.arange(-0.5, 2, 0.05) , label='otpmz-defa: test', alpha=0.5, )
# plt.xlabel("KGE' difference")
# plt.ylabel('Basin number')
# # plt.plot([0,0],[0, 20], 'k')
# plt.legend()

# plt.tight_layout()
# plt.show()

# %% [markdown]
# # test comparison

# %%
met = 'kge'
r1 = 1
r2 = 2
t1 = 'train'
t2 = 'test_5y'

d1 = df_optmz[ (df_optmz['eval']==t1) & (df_optmz['param']==f'normKGEr{r1}')][met].values
d2 = df_optmz[ (df_optmz['eval']==t1) & (df_optmz['param']==f'normKGEr{r2}')][met].values

d3 = df_optmz[ (df_optmz['eval']==t2) & (df_optmz['param']==f'normKGEr{r1}')][met].values
d4 = df_optmz[ (df_optmz['eval']==t2) & (df_optmz['param']==f'normKGEr{r2}')][met].values

print(np.nanmean( np.abs(d1-d3)), np.nanmean( np.abs(d2-d4)), )
print(np.nanmean( np.abs(d1-d2)), np.nanmean( np.abs(d3-d4)), )

# plt.scatter(d1, d2, alpha=0.5, label='train')
# plt.scatter(d3, d4, alpha=0.5, label='test')
plt.scatter(d1, d3, alpha=0.5, label=f'r{r1}')
plt.scatter(d2, d4, alpha=0.5, label=f'r{r2}')
plt.xlim(-1,1)
plt.ylim(-1,1)

plt.legend()
plt.show()
# Out:
# 0.22323677977171485 0.2801255526555902
# 0.0805569787803625 0.09301784876137832

# %%
df_optmz
# Out:
#          kge        mae     n_mae       nse        cc       rmse  \
# 0   0.399307  45.022526  0.831636 -0.593471  0.436972  74.768590
# 0   0.402628  38.588288  0.888515 -0.556043  0.440687  64.968616
# 0   0.425256  37.162979  0.786216 -0.658452  0.501259  60.581973
# 0   0.413309  38.273823  0.867499 -0.557307  0.458041  64.126289
# 0   0.385271  47.051491  0.869115 -0.734553  0.458774  78.396955
# ..       ...        ...       ...       ...       ...        ...
# 0   0.649752  32.632102  0.513315  0.578755  0.776521  69.973291
# 0   0.664365  31.506585  0.492651  0.603722  0.792024  68.615113
# 0   0.654637  32.805906  0.512679  0.584546  0.779722  70.307817
# 0   0.615256  32.755949  0.516493  0.540054  0.756339  68.781546
# 0   0.650200  32.631313  0.513302  0.579402  0.776891  69.919491
#
#     max_mon_abs_err  n_max_mon_abs_err     q90_mae    q10_mae  ...  \
# 0         88.544903           1.639035  115.132109  47.657070  ...
# 0         69.352306           1.599906  103.128567  40.905863  ...
# 0         58.216528           1.234864   96.134734  39.702617  ...
# 0         65.992224           1.498788  102.007191  40.598629  ...
# 0         83.545272           1.546488  121.893137  49.960105  ...
# ..              ...                ...         ...        ...  ...
# 0         45.819189           0.717387  144.471180  36.045641  ...
# 0         69.539759           1.086318  137.134962  34.921132  ...
# 0         48.931371           0.760623  146.347735  36.222602  ...
# 0         55.797799           0.877903  133.224525  36.211810  ...
# 0         45.847153           0.717825  144.197665  36.043976  ...
#
#     mae_summer  mae_winter  mae_spring  mae_autumn  ge_q25_mae  ge_q50_mae  \
# 0    25.005640   25.143089   86.332839   43.095152   51.832182   60.621077
# 0    25.206889   18.051596   76.640554   33.650542   44.910983   54.159827
# 0    29.233077   15.740850   67.946523   35.119315   43.387726   50.727615
# 0    25.909867   17.535445   75.041195   33.853778   44.537942   53.403401
# 0    25.136245   31.075144   83.338539   47.460052   54.914342   64.476395
# ..         ...         ...         ...         ...         ...         ...
# 0     6.992335   64.233663   35.206114   24.697038   42.153298   58.141732
# 0     6.066828   68.206190   29.439572   23.037928   40.521602   55.990246
# 0     6.834333   66.970626   33.190101   24.888289   42.382777   58.547545
# 0     8.401316   50.301763   46.846418   25.795203   42.168734   57.747643
# 0     6.986475   64.165379   35.211582   24.761800   42.146811   58.154950
#
#     ge_q75_mae  basin       eval      param
# 0    81.856566      0    test_5y  normKGEr1
# 0    72.285297      0  test_ally  normKGEr1
# 0    64.897051      0      train  normKGEr1
# 0    71.094016      0       ally  normKGEr1
# 0    90.036328      0    test_5y  normKGEr2
# ..         ...    ...        ...        ...
# 0    92.166095    626       ally  normKGEr4
# 0    86.727499    626    test_5y  normKGEr5
# 0    92.748096    626  test_ally  normKGEr5
# 0    89.738969    626      train  normKGEr5
# 0    92.057648    626       ally  normKGEr5
#
# [12540 rows x 27 columns]
