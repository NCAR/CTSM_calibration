# %%
path_MOASMO = '/glade/u/home/guoqiang/CTSM_repos/ctsm_optz/MO-ASMO/src'
sys.path.append(path_MOASMO)
import sampling
import gp
import NSGA2
import pandas as pd

import matplotlib.pyplot as plt
import numpy as np
import pickle
from MOASMO_parameters import *


def read_parameter_csv(file_parameter_list):
    df_calibparam = pd.read_csv(file_parameter_list)
    for c in ['Upper', 'Lower', 'Factor', 'Value']:
        if c in df_calibparam.columns:
            if isinstance(df_calibparam.iloc[0][c], str):
                arr = []
                for i in range(len(df_calibparam)):
                    vi = df_calibparam.iloc[i][c]
                    if ',' in vi:
                        arr.append(np.array(vi.split(',')).astype(np.float64))
                    elif '[' in vi:
                        arr.append(np.array(vi.strip('[]').replace('\n', '').split(), dtype=np.float64))
                    else:
                        try:
                            arr.append(np.array([np.float64(vi)]))
                        except:
                            arr.append(np.array([-99999]))
                df_calibparam[c] = arr
    return df_calibparam

# %%
param_infofile = '/glade/u/home/guoqiang/CTSM_repos/moasmo_test/param_ASG_20221206_moasmo.csv'
param_filelist = ['/glade/work/guoqiang/CTSM_cases/MOASMO_CESM/CAMELS50/ctsm_outputs/iter0_all_meanparam.csv']
metric_filelist = ['/glade/work/guoqiang/CTSM_cases/MOASMO_CESM/CAMELS50/ctsm_outputs/iter0_all_metric.csv']

# %%
    pop = 100
    gen = 100
    crossover_rate = 0.9
    mu = 20
    mum = 20

    # define hyperparameter
    alpha = 1e-3
    leng_lb = 1e-3
    leng_ub = 1e3
    nu = 2.5

    N_resample = 20 # number of selected optimal points

# %%
    # input data x (parameter sets) and output data y (objective function values)
    df_param = pd.concat(map(pd.read_csv, param_filelist))
    df_metric = pd.concat(map(pd.read_csv, metric_filelist))
    df_info = read_parameter_csv(param_infofile)

    param_names = df_info['Parameter'].values # exclude binded parameters
    df_param = df_param[param_names]

    xlb = np.array([np.nanmean(v) for v in df_info['Lower']])
    xub = np.array([np.nanmean(v) for v in df_info['Upper']])

    x = df_param.to_numpy()
    y = df_metric.to_numpy()
    
    nInput = x.shape[1]
    nOutput = y.shape[1]

# %%
    from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
    sm = RandomForestRegressor()
    sm.fit(x, y)
# Out:
# RandomForestRegressor()

# %%
    # perform optimization using the surrogate model
    bestx_sm, besty_sm, x_sm, y_sm = NSGA2.optimization(sm, nInput, nOutput, xlb, xub, pop, gen, crossover_rate, mu, mum)
    D = NSGA2.crowding_distance(besty_sm)
    idxr = D.argsort()[::-1][:N_resample]
    x_resample = bestx_sm[idxr, :]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [59], in <cell line: 2>()
#       1 # perform optimization using the surrogate model
# ----> 2 bestx_sm, besty_sm, x_sm, y_sm = NSGA2.optimization(sm, nInput, nOutput, xlb, xub, pop, gen, crossover_rate, mu, mum)
#       3 D = NSGA2.crowding_distance(besty_sm)
#       4 idxr = D.argsort()[::-1][:N_resample]
#
# File ~/CTSM_repos/ctsm_optz/MO-ASMO/src/NSGA2.py:64, in optimization(model, nInput, nOutput, xlb, xub, pop, gen, crossover_rate, mu, mum)
#      61         count += 1
#      62         icall += 1
#      63 population_para, population_obj = \
# ---> 64     remove_worst(population_para, population_obj, pop, nInput, nOutput)
#      65 bestx = population_para.copy()
#      66 besty = population_obj.copy()
#
# File ~/CTSM_repos/ctsm_optz/MO-ASMO/src/NSGA2.py:256, in remove_worst(population_para, population_obj, pop, nInput, nOutput)
#     253 def remove_worst(population_para, population_obj, pop, nInput, nOutput):
#     254     ''' remove the worst individuals in the population '''
#     255     population_para, population_obj, rank, crowd = \
# --> 256         sortMO(population_para, population_obj, nInput, nOutput)
#     257     return population_para[0:pop,:], population_obj[0:pop,:]
#
# File ~/CTSM_repos/ctsm_optz/MO-ASMO/src/NSGA2.py:76, in sortMO(x, y, nInput, nOutput)
#      69 def sortMO(x, y, nInput, nOutput):
#      70     ''' Non domination sorting for multi-objective optimization
#      71         x: input parameter matrix
#      72         y: output objectives matrix
#      73         nInput: number of input
#      74         nOutput: number of output
#      75     '''
# ---> 76     rank, dom = fast_non_dominated_sort(y)
#      77     idxr = rank.argsort()
#      78     rank = rank[idxr]
#
# File ~/CTSM_repos/ctsm_optz/MO-ASMO/src/NSGA2.py:120, in fast_non_dominated_sort(Y)
#     118     dom[i,j] = 1
#     119     Sp.append(j)
# --> 120 elif dominates(Y[j,:], Y[i,:]):
#     121     dom[i,j] = 2
#     122     n[i] += 1
#
# File ~/CTSM_repos/ctsm_optz/MO-ASMO/src/NSGA2.py:153, in dominates(p, q)
#     147 def dominates(p,q):
#     148     ''' comparison for multi-objective optimization
#     149         d = True, if p dominates q
#     150         d = False, if p not dominates q
#     151         p and q are 1*nOutput array
#     152     '''
# --> 153     if sum(p > q) == 0:
#     154         d = True
#     155     else:
#
# KeyboardInterrupt:

# %%
# surrogate model using RF based on all samples

fig, ax = plt.subplots(2, 2, figsize=[8, 8])
ax = ax.flatten()

sm1 = RandomForestRegressor()
sm1.fit(x, y[:,0])
ax[0].scatter(y[:,0], sm1.predict(x))
ax[0].plot([0, 3], [0, 3])


ax[1].scatter(y[:,0], sm.predict(x)[:,0])
ax[1].plot([0, 3], [0, 3])

sm2 = RandomForestRegressor()
sm2.fit(x, y[:,1])
ax[2].scatter(y[:,1], sm2.predict(x))
ax[2].plot([4, 8], [4, 8])

ax[3].scatter(y[:,1], sm.predict(x)[:,1])
ax[3].plot([4, 8], [4, 8])

# %%
# cross validation of surrogate model using RF and GPR

from sklearn.model_selection import KFold
kf = KFold(n_splits=5)
kf.get_n_splits(x)


fig, ax = plt.subplots(5, 2, figsize=[8, 12])
ax = ax.flatten()

for i, (train_index, test_index) in enumerate(kf.split(x)):
    # print(f"Fold {i}:")
    # print(f"  Train: index={train_index}")
    # print(f"  Test:  index={test_index}")
    
    smi = RandomForestRegressor()
    smi.fit(x[train_index,:], y[train_index,0])
    ax[i*2].scatter(y[test_index,0], smi.predict(x[test_index,:]))
    ax[i*2].plot([0, 3], [0, 3])
    ax[i*2].set_title(f'RF fold {i} for metric-1')
    
    smi = RandomForestRegressor()
    smi.fit(x[train_index,:], y[train_index,1])
    ax[i*2+1].scatter(y[test_index,1], smi.predict(x[test_index,:]))
    ax[i*2+1].plot([4, 8], [4, 8])
    ax[i*2+1].set_title(f'RF fold {i} for metric-2')
    
plt.tight_layout()
plt.show()

# %%
# cross validation of surrogate model using GPR
from sklearn.gaussian_process.kernels import DotProduct, WhiteKernel, Matern
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.model_selection import KFold

from sklearn.preprocessing import StandardScaler

def calculate_rmse(y_true, y_pred):
    """Calculate the Root Mean Squared Error (RMSE) between true values and predicted values."""
    mse = np.mean((y_true - y_pred) ** 2)
    rmse = np.sqrt(mse)
    return rmse




kf = KFold(n_splits=5)
kf.get_n_splits(x)

fig, ax = plt.subplots(5, 2, figsize=[8, 12])
ax = ax.flatten()

for i, (train_index, test_index) in enumerate(kf.split(x)):
    
    scaler = StandardScaler()
    scaler.fit(x[train_index, :])

    x_train = scaler.transform(x[train_index, :])
    y_train = y[train_index, :]
    
    x_test= scaler.transform(x[test_index, :])
    y_test = y[test_index, :]
    

    # kernel = DotProduct() + WhiteKernel()
    # kernel = 1.0 * Matern(length_scale=1.0, nu=1.5)
    # smi = GaussianProcessRegressor(kernel=kernel)
    kernel = Matern(length_scale=1.0, nu=1.5)
    smi = GaussianProcessRegressor(kernel=kernel, alpha=0.1)
    smi.fit(x_train, y_train[:,0])
    rmse = calculate_rmse(y_test[:,0], smi.predict(x_test))
    ax[i*2].scatter(y_test[:,0], smi.predict(x_test), label=f'GPR: RMSE={rmse:.3f}')
    
    smi = RandomForestRegressor()
    smi.fit(x_train, y_train[:,0])
    rmse = calculate_rmse(y_test[:,0], smi.predict(x_test))
    ax[i*2].scatter(y_test[:,0], smi.predict(x_test), label=f'RF: RMSE={rmse:.3f}')
    
    
    ax[i*2].plot([0, 3], [0, 3])
    ax[i*2].set_title(f'k fold {i} for metric-1')
    
    ax[i*2].legend()
    
    # kernel = DotProduct() + WhiteKernel()
    kernel = 1.0 * Matern(length_scale=1.0, nu=1.5)
    smi = GaussianProcessRegressor(kernel=kernel, )
    smi.fit(x_train, y_train[:,1])
    rmse = calculate_rmse(y_test[:,0], smi.predict(x_test))
    ax[i*2+1].scatter(y_test[:,1], smi.predict(x_test), label=f'GPR: RMSE={rmse:.3f}')
    
    smi = RandomForestRegressor()
    smi.fit(x_train, y_train[:,1])
    rmse = calculate_rmse(y_test[:,0], smi.predict(x_test))
    ax[i*2+1].scatter(y_test[:,1], smi.predict(x_test), label=f'RF: RMSE={rmse:.3f}')
    
    ax[i*2+1].plot([4, 8], [4, 8])
    ax[i*2+1].set_title(f'k fold {i} for metric-2')
    
    ax[i*2+1].legend()
    
plt.tight_layout()
plt.show()
