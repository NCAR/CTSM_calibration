# %%
import os, sys, subprocess
import numpy as np
import pandas as pd
import xarray as xr

# import MO-ASMO functions
path_MOASMO = '/glade/u/home/guoqiang/model_sources/MO-ASMO/src'
sys.path.append(path_MOASMO)
import sampling

# %%
def get_parameter_from_Namelist_or_lndin(name, file_user_nl_clm, file_lndin, type='number'):
    # check Namelist file first, and then check
    with open(file_user_nl_clm, 'r') as f:
        for l in f:
            l = l.strip()
            if l.startswith(name):
                if type == 'number':
                    value = np.array(float(l.split('=')[-1].strip().replace('\'', '')))
                elif type == 'str':
                    value = l.split('=')[-1].strip().replace('\'', '')
                flag = True
                break
    if not flag:
        with open(file_lndin, 'r') as f:
            for l in f:
                l = l.strip()
                if l.startswith(name):
                    value = np.array(float(l.split('=')[-1].strip().replace('\'', '')))
                elif type == 'str':
                    value = l.split('=')[-1].strip().replace('\'', '')
                    break
    return value


def get_parameter_value_from_CTSM_case(param_name, param_source, path_CTSM_case):
    # get the parameter values of an existing CTSM case

    file_user_nl_clm = f'{path_CTSM_case}/user_nl_clm'
    file_lndin = f'{path_CTSM_case}/Buildconf/clmconf/lnd_in'

    if param_source == 'Namelist':
        param_value = get_parameter_from_Namelist_or_lndin(param_name, file_user_nl_clm, file_lndin, 'number')
    elif param_source == 'Param':
        paramfile = get_parameter_from_Namelist_or_lndin('paramfile', file_user_nl_clm, file_lndin, 'str')
        with xr.open_dataset(paramfile) as ds:
            param_value = ds[param_name].values
    elif param_source == 'Surfdata':
        fsurdat = get_parameter_from_Namelist_or_lndin('fsurdat', file_user_nl_clm, file_lndin, 'str')
        with xr.open_dataset(fsurdat) as ds:
            param_value = ds[param_name].values
    else:
        sys.exit(f'Unknown param_source: {param_source}')

    return param_value


def check_and_generate_binded_parameters(df_param, path_CTSM_case):
    # check if there is any binded variable
    # if there is, add binded variables to df_calibparam
    # it is assumed that binded variables have the same parameter range so we can scale them equally
    if 'Binding' in df_param.columns:
        df_bind = pd.DataFrame()
        for i in range(len(df_param)):
            rawvari_value = get_parameter_value_from_CTSM_case(df_param.iloc[i]['Parameter'], df_param.iloc[i]['Source'], path_CTSM_case)
            bindvari = df_param.iloc[i]['Binding']
            if bindvari != 'None':
                bindvari = bindvari.split(',')
                for bv in bindvari:
                    dftmp = df_param.iloc[[i]].copy()
                    dftmp['Parameter'] = bv
                    # mask other cols
                    for col in ['Default', 'Lower', 'Upper', 'Binding', 'Parameter_Ost']:
                        if col in dftmp.columns:
                            dftmp[col] = 'None'
                    # generate parameter values
                    bind_var_value0 = get_parameter_value_from_CTSM_case(bv, dftmp['Source'].values[0], path_CTSM_case)
                    dftmp['Value'] = bind_var_value0 + (df_param.iloc[i]['Value'] - rawvari_value)
                    print(f"bv:{bv}, rawvari_value:{rawvari_value}, bind_var_value0:{bind_var_value0}, df_paramvalue:{df_param.iloc[i]['Value']}")
                    df_bind = pd.concat([df_bind, dftmp])

        df_param = pd.concat([df_param, df_bind])

    return df_param


########################################################################################################################
# Initial sampling:
# Generate a TXN matrix X using the Good Lattice Points method with RGS de-correlation,
# where T is the number of sample points. Run the dynamic model for T times and obtain the multiobjective results Y
# Y=f(X)
# where Y is a TXM matrix containing the objective functions


def read_parameter_csv(file_parameter_list):
    df_calibparam = pd.read_csv(file_parameter_list)

    for c in ['Upper', 'Lower', 'Factor', 'Value']:
        if c in df_calibparam.columns:
            if isinstance(df_calibparam.iloc[0][c], str):
                arr = []
                for i in range(len(df_calibparam)):
                    vi = df_calibparam.iloc[i][c]
                    if ',' in vi:
                        arr.append(np.array(vi.split(',')).astype(np.float64))
                    elif '[' in vi:
                        arr = np.array(vi.strip('[]').split().replace('\n', ''), dtype=np.float64)
                    else:
                        arr.append(np.array([np.float64(vi)]))
                df_calibparam[c] = arr

    return df_calibparam


def generate_initial_parameter_sets(file_parameter_list, sampling_method, outpath, path_CTSM_case='', num_init=-1):
    # example parameters
    # sampling_method = 'lh'  # lh: LatinHypercubeDesign, slh: SymmetricLatinHypercubeDesign, glp: GoodLatticePointsDesign
    # param_upper_bound = {'param1': np.array(15), 'param2': np.array([1, 2, 3])}
    # param_lower_bound = {'param1': np.array(3), 'param2': np.array([0.2, 1.5, 2.2])}
    # path_CTSM_case must be provided if there are any binded parameters for calibration

    df_calibparam = read_parameter_csv(file_parameter_list)
    param_upper_bound = df_calibparam['Upper'].values
    param_lower_bound = df_calibparam['Lower']

    # dimension sizes
    num_param = len(param_lower_bound) # number of parameters to be calibrated
    if not num_init > 0:
        num_init = num_param * 20 # number of initial samples (i.e., initial model runs). A proper initial sample size should be 15–20 times the number of parameters (Gong et al., 2015)

    # get initial factors between 0 and 1 which will be used to scale real parameters
    # init_factors: [num_init, num_param]
    if sampling_method == 'lh':
        init_factors = sampling.lh(num_init, num_param)
    elif sampling_method == 'slh':
        init_factors = sampling.slh(num_init, num_param)
    elif sampling_method == 'glp': # glp is used by Gong et al., 2015
        init_factors = sampling.glp(num_init, num_param)
    else:
        sys.exit('Unknown sampling method!')

    # save factors
    df_factor = pd.DataFrame(init_factors, columns=df_calibparam['Parameter'].values)
    df_factor.to_csv(f'{outpath}/paramset_iter0_scalefactors.csv', index=False)

    # generate a dataframe for every set of parameters and deal with binding parameters
    os.makedirs(outpath, exist_ok=True)
    for i in range(num_init):
        outfile = f'{outpath}/paramset_iter0_trial{i}.csv'
        print('Generating parameter file:', outfile)
        dfi = df_calibparam.copy()
        dfi['Factor'] = init_factors[i, :]
        dfi['Value'] = init_factors[i, :] * (param_upper_bound - param_lower_bound) + param_lower_bound

        # process binded parameters
        dfi = check_and_generate_binded_parameters(dfi, path_CTSM_case)



        dfi.to_csv(outfile, index=False)

# %%
file_parameter_list = '/glade/u/home/guoqiang/CTSM_repos/moasmo_test/param_ASG_20221206_moasmo.csv'
sampling_method = 'glp'
outpath = '/glade/scratch/guoqiang/moasmo_test/param_sets'
path_CTSM_case = '/glade/work/guoqiang/CTSM_cases/CAMELS_Calib/Lump_calib_split_nest_LMWG/CAMELS_100'
num_init=200
# generate_initial_parameter_sets(file_parameter_list, sampling_method, outpath, path_CTSM_case, num_init=200)

# %%
    df_calibparam = read_parameter_csv(file_parameter_list)
    param_upper_bound = df_calibparam['Upper'].values
    param_lower_bound = df_calibparam['Lower']

    # dimension sizes
    num_param = len(param_lower_bound) # number of parameters to be calibrated
    if not num_init > 0:
        num_init = num_param * 20 # number of initial samples (i.e., initial model runs). A proper initial sample size should be 15–20 times the number of parameters (Gong et al., 2015)

    # get initial factors between 0 and 1 which will be used to scale real parameters
    # init_factors: [num_init, num_param]
    if sampling_method == 'lh':
        init_factors = sampling.lh(num_init, num_param)
    elif sampling_method == 'slh':
        init_factors = sampling.slh(num_init, num_param)
    elif sampling_method == 'glp': # glp is used by Gong et al., 2015
        init_factors = sampling.glp(num_init, num_param)
    else:
        sys.exit('Unknown sampling method!')

    # save factors
    df_factor = pd.DataFrame(init_factors, columns=df_calibparam['Parameter'].values)
    df_factor.to_csv(f'{outpath}/paramset_iter0_scalefactors.csv', index=False)

# %%
    # generate a dataframe for every set of parameters and deal with binding parameters
    os.makedirs(outpath, exist_ok=True)
    for i in range(num_init):
        outfile = f'{outpath}/paramset_iter0_trial{i}.csv'
        print('Generating parameter file:', outfile)
        dfi = df_calibparam.copy()
        dfi['Factor'] = init_factors[i, :]
        dfi['Value'] = init_factors[i, :] * (param_upper_bound - param_lower_bound) + param_lower_bound

        # process binded parameters
        dfi = check_and_generate_binded_parameters(dfi, path_CTSM_case)



        dfi.to_csv(outfile, index=False)
# Out:
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial0.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.39]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.39]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.39]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial1.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.77]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.77]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.77]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial2.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.15]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.15]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.15]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial3.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.53]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.53]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.53]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial4.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.91]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.91]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.91]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial5.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.29]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.29]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.29]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial6.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.69]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.69]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.69]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial7.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.07]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.07]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.07]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial8.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.45]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.45]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.45]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial9.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.83]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.83]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.83]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial10.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.21]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.21]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.21]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial11.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.59]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.59]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.59]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial12.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.99]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.99]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.99]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial13.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.37]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.37]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.37]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial14.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.75]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.75]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.75]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial15.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.13]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.13]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.13]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial16.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.51]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.51]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.51]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial17.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.89]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.89]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.89]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial18.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.27]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.27]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.27]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial19.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.67]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.67]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.67]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial20.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.05]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.05]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.05]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial21.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.43]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.43]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.43]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial22.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.81]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.81]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.81]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial23.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.19]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.19]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.19]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial24.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.57]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.57]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.57]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial25.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.97]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.97]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.97]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial26.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.35]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.35]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.35]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial27.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.73]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.73]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.73]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial28.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.11]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.11]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.11]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial29.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.49]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.49]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.49]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial30.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.87]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.87]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.87]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial31.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.25]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.25]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.25]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial32.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.65]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.65]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.65]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial33.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.03]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.03]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.03]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial34.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.41]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.41]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.41]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial35.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.79]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.79]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.79]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial36.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.17]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.17]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.17]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial37.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.55]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.55]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.55]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial38.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.95]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.95]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.95]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial39.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.33]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.33]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.33]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial40.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.71]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.71]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.71]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial41.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.09]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.09]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.09]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial42.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.47]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.47]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.47]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial43.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.85]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.85]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.85]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial44.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.23]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.23]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.23]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial45.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.63]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.63]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.63]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial46.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.01]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.01]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.01]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial47.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.39]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.39]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.39]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial48.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.77]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.77]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.77]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial49.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.15]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.15]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.15]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial50.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.53]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.53]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.53]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial51.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.93]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.93]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.93]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial52.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.31]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.31]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.31]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial53.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.69]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.69]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.69]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial54.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.07]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.07]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.07]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial55.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.45]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.45]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.45]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial56.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.83]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.83]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.83]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial57.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.21]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.21]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.21]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial58.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.61]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.61]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.61]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial59.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.99]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.99]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.99]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial60.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.37]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.37]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.37]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial61.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.75]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.75]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.75]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial62.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.13]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.13]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.13]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial63.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.51]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[0.51]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[0.51]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial64.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.91]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.91]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.91]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial65.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.29]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[3.29]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[3.29]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial66.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.67]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.67]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.67]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial67.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.05]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[2.05]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[2.05]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_trial68.csv
# bv:precip_repartition_glc_all_rain_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.43]
# bv:precip_repartition_glc_all_snow_t, rawvari_value:2.0, bind_var_value0:-2.0, df_paramvalue:[1.43]
# bv:precip_repartition_nonglc_all_snow_t, rawvari_value:2.0, bind_var_value0:0.0, df_paramvalue:[1.43]
# Generating parameter file: /glade/scratch/guoqiang/moasmo_test/param_sets/paramset_iter0_tr