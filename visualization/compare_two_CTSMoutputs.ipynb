# %%
import xarray as xr
import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
inpath1 = '/glade/scratch/guoqiang/CTSM_outputs/CAMELS_Calib/Distr_Calib_no_nest/hillslope_SS587_E5EMforc/run'
inpath2 = '/glade/scratch/guoqiang/CTSM_outputs/CAMELS_Calib/Distr_Calib_no_nest/archive/hillslope_SS587-backup/lnd/hist/'

# %%
year = 195
infiles1 = glob.glob(f'{inpath1}/*h0*{year}*.nc')
infiles2 = glob.glob(f'{inpath2}/*h0*{year}*.nc')
infiles1.sort()
infiles2.sort()

ds1 = xr.open_mfdataset(infiles1)
ds2 = xr.open_mfdataset(infiles2)

# %%
ds1.QRUNOFF.mean(dim='lndgrid').plot(label='E5LEME')
ds2.QRUNOFF.mean(dim='lndgrid').plot(label='GSWP3')
plt.legend()
plt.show()

# %%
ds1.FSNO.mean(dim='lndgrid').plot(label='E5LEME')
ds2.FSNO.mean(dim='lndgrid').plot(label='GSWP3')
plt.legend()
plt.show()

# %%
ds1.TBOT.mean(dim='lndgrid').plot(label='E5LEME')
ds2.TBOT.mean(dim='lndgrid').plot(label='GSWP3')
plt.legend()
plt.show()

# %%
ds1.QSOIL.mean(dim='lndgrid').plot(label='E5LEME')
ds2.QSOIL.mean(dim='lndgrid').plot(label='GSWP3')
plt.legend()
plt.show()

# %%
ds1
# Out:
# <xarray.Dataset>
# Dimensions:                        (levgrnd: 25, levsoi: 20, levlak: 10,
#                                     levdcmp: 1, time: 108, hist_interval: 2,
#                                     lndgrid: 587, cft: 64, glc_nec: 10,
#                                     ltype: 9, natpft: 15, nvegwcs: 4)
# Coordinates:
#   * levgrnd                        (levgrnd) float32 0.01 0.04 ... 28.87 42.0
#   * levsoi                         (levsoi) float32 0.01 0.04 0.09 ... 6.94 8.03
#   * levlak                         (levlak) float32 0.05 0.6 2.1 ... 34.33 44.78
#   * levdcmp                        (levdcmp) float32 1.0
#   * time                           (time) object 1951-02-01 00:00:00 ... 1960...
# Dimensions without coordinates: hist_interval, lndgrid, cft, glc_nec, ltype,
#                                 natpft, nvegwcs
# Data variables: (12/263)
#     mcdate                         (time) float64 dask.array<chunksize=(2,), meta=np.ndarray>
# ...
